# %% [markdown]
# <img src='img/Screen Shot 2021-10-28 at 1.27.55 AM.png'>

# %%
import matplotlib.pyplot as plt; #plt.style.use('seaborn')
import numpy as np; np.random.seed(0)
import pandas as pd
from scipy import stats

# %%
size = 10000
mu = 5
sigma = 2

if 0:
    x = stats.norm.rvs(loc=mu, scale=sigma, size=size)
elif 1:
    x = stats.t.rvs(3, loc=mu, scale=sigma, size=size)
elif 1:
    x = stats.t.rvs(20, loc=mu, scale=sigma, size=size)
elif 1:
    x = stats.uniform.rvs(size=size)

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.66-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: pandas>=0.24 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.2.4)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.10.tar.gz (8.2 kB)
# Requirement already satisfied: lxml>=4.5.1 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: requests>=2.20 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (2.25.1)
# Requirement already satisfied: numpy>=1.15 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/sungchullee/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (4.0.0)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8488 sha256=23f1c6ccfe89006a8de84573242fa8e0f615f2d90b294fd8c0688c00f11ac0cf
#   Stored in directory: /Users/sungchullee/Library/Caches/pip/wheels/21/c9/66/b41c847de65c7985db52ec21d59996841598b8b0e93f2b9500
# Successfully built multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.10 yfinance-0.1.66

# %%
import yfinance as yf
x = yf.Ticker('AAPL').history(period='max').Close.pct_change()

# %%
from statsmodels.graphics.gofplots import qqplot
qqplot(x, line='s');

# %%
import statsmodels.api as sm
sm.qqplot(x, line='s')
plt.grid(True)
plt.xlabel('theoretical quantiles')
plt.ylabel('sample quantiles');

# %% [markdown]
# # Reference
#
# [wiki](https://en.wikipedia.org/wiki/Normality_test)
#
# [Ben_Lambert](https://www.youtube.com/watch?v=TyjYI7yjFZI)
#
# [Thomas_Haslwanter](https://github.com/thomas-haslwanter/statsintro_python)
#
# [scipy.stats.probplot](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.probplot.html)
