# %% [markdown]
# <img src='img/Screen Shot 2021-10-28 at 2.05.11 AM_2.png'>

# %%
import matplotlib.pyplot as plt; plt.style.use('seaborn')
import numpy as np; np.random.seed(0)
import pandas as pd
from scipy import stats

# %%
data1 = np.random.rand(500) * 1000

# %%
if 0:
    data2 = (data1 + (np.random.rand(500) * 10))**3
elif 0:
    data2 = np.sin(data1 + (np.random.rand(500) * 10))
elif 1:
    data2 = np.sin(data1)

# %%
plt.scatter(data1, data2);

# %%
data = {'data1': data1, 'data2': data2}
df = pd.DataFrame(data)

# %%
df.corr(method='pearson')
# Out:
#           data1     data2
# data1  1.000000 -0.021677
# data2 -0.021677  1.000000

# %%
df.corr(method='spearman')
# Out:
#           data1     data2
# data1  1.000000 -0.029368
# data2 -0.029368  1.000000

# %%
df.corr(method='kendall')
# Out:
#           data1     data2
# data1  1.000000 -0.017731
# data2 -0.017731  1.000000

# %% [markdown]
# <img src='img/Screen Shot 2021-11-21 at 8.16.07 PM.png'>
#
# [wiki](https://en.wikipedia.org/wiki/Kendall_rank_correlation_coefficient)

# %% [markdown]
# <img src='img/Screen Shot 2021-11-21 at 8.16.33 PM.png'>
#
# [wiki](https://en.wikipedia.org/wiki/Kendall_rank_correlation_coefficient)

# %% [markdown]
# <img src='img/Screen Shot 2021-11-19 at 3.56.41 PM.png'>
#
# [DOC](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kendalltau.html)

# %%
stat, pval = stats.kendalltau(data1, data2)
stat, pval
# Out:
# (-0.0177314629258517, 0.5534110429411117)

# %% [markdown]
# # Reference
#
# [Understandable_Statistics](https://www.youtube.com/watch?v=-FMeXUcZC48&list=PL4BztsgicSEeC4Oic6s5vW4LE-0YZTuo-&index=16)
#
# [Jason_Brownlee](https://machinelearningmastery.com/how-to-calculate-nonparametric-rank-correlation-in-python/)
#
# [scipy](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.spearmanr.html)
